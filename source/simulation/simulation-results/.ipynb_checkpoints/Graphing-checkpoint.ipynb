# %%
import seaborn as sns
import pandas as pd
import csv
import os
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("results_local_episodes.csv")
df
# Out:
#        local_episodes  trial  epoch  average_device_train_accuracy  \
# 0                   1      0      0                          0.400
# 1                   1      0      1                          0.425
# 2                   1      0      2                          0.625
# 3                   1      0      3                          0.575
# 4                   1      0      4                          0.575
# ...               ...    ...    ...                            ...
# 11995               3     19    195                          0.750
# 11996               3     19    196                          0.900
# 11997               3     19    197                          0.875
# 11998               3     19    198                          0.850
# 11999               3     19    199                          0.900
#
#        average_device_val_accuracy
# 0                           0.5575
# 1                           0.4575
# 2                           0.5675
# ...

# %%
sns.relplot(
    data=df, x="epoch", y="signal",
    hue="local_episodes", style="event", kind="line",
)
